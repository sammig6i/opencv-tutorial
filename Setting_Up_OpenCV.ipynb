# %% [markdown]
# # 1. Installing

# %%
# !pip install opencv-python
# Out:
# ...
#   Using cached opencv_python-4.9.0.80-cp37-abi3-macosx_10_16_x86_64.whl.metadata (20 kB)
# ...
# Using cached opencv_python-4.9.0.80-cp37-abi3-macosx_10_16_x86_64.whl (55.7 MB)
# ...

# %%
# !conda list
# Out:
# # packages in environment at /Users/samghazzawi/anaconda3:
# #
# # Name                    Version                   Build  Channel
# _anaconda_depends         2024.02         py311_openblas_1
# abseil-cpp                20230802.0           h61975a4_2
# accessible-pygments       0.0.4              pyhd8ed1ab_0    conda-forge
# aiobotocore               2.7.0           py311hecd8cb5_0
# aiohttp                   3.9.3           py311h6c40b1e_0
# aioitertools              0.7.1              pyhd3eb1b0_0
# aiosignal                 1.2.0              pyhd3eb1b0_0
# alabaster                 0.7.12             pyhd3eb1b0_0
# altair                    5.0.1           py311hecd8cb5_0
# anaconda-anon-usage       0.4.3           py311hfb7c958_100
# anaconda-catalogs         0.2.0           py311hecd8cb5_0
# anaconda-client           1.12.3          py311hecd8cb5_0
# anaconda-cloud-auth       0.1.4           py311hecd8cb5_0
# anaconda-navigator        2.5.2           py311hecd8cb5_0
# ...

# %%
import cv2

# %%
cv2.VideoCapture
# Out:
# cv2.VideoCapture

# %% [markdown]
# # 2. Test Samples

# %%
# histogram sample 
# !cd /Users/samghazzawi/Desktop/opencv-tutorial/opencv-4.9.0/samples/python
 
# !python hist.py

# %%
# optical flow sample
# !python /Users/samghazzawi/Desktop/opencv-tutorial/opencv-4.9.0/samples/python/opt_flow.py 0
# Out:
# example to show optical flow
#
# USAGE: opt_flow.py [<video_source>]
#
# Keys:
#  1 - toggle HSV flow visualization
#  2 - toggle glitch
#
# Keys:
#     ESC    - exit
#
# HSV flow visualization is on
# ^C
# Traceback (most recent call last):
#   File "/Users/samghazzawi/Desktop/opencv-tutorial/opencv-4.9.0/samples/python/opt_flow.py", line 103, in <module>
#     main()
#   File "/Users/samghazzawi/Desktop/opencv-tutorial/opencv-4.9.0/samples/python/opt_flow.py", line 74, in main
#     _ret, img = cam.read()
#                 ^^^^^^^^^^
# KeyboardInterrupt
